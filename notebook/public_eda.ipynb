# %%
# Imports: regex utilities, pandas, and pathlib for file paths
import re
import pandas as pd
from pathlib import Path

# %%
# Source Excel file path for public sector vacancies
file_path = Path('../data/Actual/raw/public_sector.xlsx')

# %%
# Load the raw worksheet into a DataFrame
#   - sheet_name: source tab
#   - header: first row contains column names
df = pd.read_excel(file_path, sheet_name="Data1", header=0)

# %%
# Drop the first 9 rows (metadata in the sheet) and reset the index
df = df.iloc[9:].reset_index(drop=True)

# %%
# Quick preview to confirm header and data alignment
df.head()
# Out:
#             Unnamed: 0 Job Vacancies ;  Public ;  New South Wales ;  \
# 0  1979-05-15 00:00:00                                          NaN
# 1  1979-08-15 00:00:00                                          NaN
# 2  1979-11-15 00:00:00                                          NaN
# 3  1980-02-15 00:00:00                                          NaN
# 4  1980-05-15 00:00:00                                          NaN
#
#   Job Vacancies ;  Public ;  Victoria ;  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Job Vacancies ;  Public ;  Queensland ;  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Job Vacancies ;  Public ;  South Australia ;  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Job Vacancies ;  Public ;  Western Australia ;  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Job Vacancies ;  Public ;  Tasmania ;  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   Job Vacancies ;  Public ;  Northern Territory ;  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Job Vacancies ;  Public ;  Australian Capital Territory ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Job Vacancies ;  Public ;  Australia ;  ...  \
# 0                                   12.3  ...
# 1                                     11  ...
# 2                                   15.4  ...
# 3                                   15.9  ...
# 4                                   13.1  ...
#
#   Job Vacancies ;  Public ;  Australia ;.2  \
# 0                                     11.7
# 1                                     12.9
# 2                                     14.1
# 3                                     14.7
# 4                                     14.2
#
#   Standard Error of Job Vacancies ;  Public ;  New South Wales ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Victoria ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Queensland ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  South Australia ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Western Australia ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Tasmania ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Northern Territory ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Australian Capital Territory ;  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Standard Error of Job Vacancies ;  Public ;  Australia ;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 21 columns]

# %%
# Inspect column names, dtypes, and non-null counts after trimming header rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 21 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Unnamed: 0                                                                   185 non-null    object
#  1   Job Vacancies ;  Public ;  New South Wales ;                                 161 non-null    object
#  2   Job Vacancies ;  Public ;  Victoria ;                                        161 non-null    object
#  3   Job Vacancies ;  Public ;  Queensland ;                                      162 non-null    object
#  4   Job Vacancies ;  Public ;  South Australia ;                                 162 non-null    object
#  5   Job Vacancies ;  Public ;  Western Australia ;                               158 non-null    object
#  6   Job Vacancies ;  Public ;  Tasmania ;                                        162 non-null    object
#  7   Job Vacancies ;  Public ;  Northern Territory ;                              162 non-null    object
#  8   Job Vacancies ;  Public ;  Australian Capital Territory ;                    162 non-null    object
#  9   Job Vacancies ;  Public ;  Australia ;                                       180 non-null    object
#  10  Job Vacancies ;  Public ;  Australia ;.1                                     180 non-null    object
#  11  Job Vacancies ;  Public ;  Australia ;.2                                     180 non-null    object
#  12  Standard Error of Job Vacancies ;  Public ;  New South Wales ;               157 non-null    object
#  13  Standard Error of Job Vacancies ;  Public ;  Victoria ;                      157 non-null    object
#  14  Standard Error of Job Vacancies ;  Public ;  Queensland ;                    158 non-null    object
#  15  Standard Error of Job Vacancies ;  Public ;  South Australia ;               158 non-null    object
#  16  Standard Error of Job Vacancies ;  Public ;  Western Australia ;             154 non-null    object
#  17  Standard Error of Job Vacancies ;  Public ;  Tasmania ;                      158 non-null    object
#  18  Standard Error of Job Vacancies ;  Public ;  Northern Territory ;            158 non-null    object
#  19  Standard Error of Job Vacancies ;  Public ;  Australian Capital Territory ;  158 non-null    object
#  20  Standard Error of Job Vacancies ;  Public ;  Australia ;                     158 non-null    object
# dtypes: object(21)
# memory usage: 30.5+ KB

# %%
# Rename the first column to a canonical "Date" and parse as datetime
time_col = df.columns[0]
df = df.rename(columns={time_col: "Date"})
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
# Validate that "Date" is datetime and review missingness after parsing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 21 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Date                                                                         185 non-null    datetime64[ns]
#  1   Job Vacancies ;  Public ;  New South Wales ;                                 161 non-null    object
#  2   Job Vacancies ;  Public ;  Victoria ;                                        161 non-null    object
#  3   Job Vacancies ;  Public ;  Queensland ;                                      162 non-null    object
#  4   Job Vacancies ;  Public ;  South Australia ;                                 162 non-null    object
#  5   Job Vacancies ;  Public ;  Western Australia ;                               158 non-null    object
#  6   Job Vacancies ;  Public ;  Tasmania ;                                        162 non-null    object
#  7   Job Vacancies ;  Public ;  Northern Territory ;                              162 non-null    object
#  8   Job Vacancies ;  Public ;  Australian Capital Territory ;                    162 non-null    object
#  9   Job Vacancies ;  Public ;  Australia ;                                       180 non-null    object
#  10  Job Vacancies ;  Public ;  Australia ;.1                                     180 non-null    object
#  11  Job Vacancies ;  Public ;  Australia ;.2                                     180 non-null    object
#  12  Standard Error of Job Vacancies ;  Public ;  New South Wales ;               157 non-null    object
#  13  Standard Error of Job Vacancies ;  Public ;  Victoria ;                      157 non-null    object
#  14  Standard Error of Job Vacancies ;  Public ;  Queensland ;                    158 non-null    object
#  15  Standard Error of Job Vacancies ;  Public ;  South Australia ;               158 non-null    object
#  16  Standard Error of Job Vacancies ;  Public ;  Western Australia ;             154 non-null    object
#  17  Standard Error of Job Vacancies ;  Public ;  Tasmania ;                      158 non-null    object
#  18  Standard Error of Job Vacancies ;  Public ;  Northern Territory ;            158 non-null    object
#  19  Standard Error of Job Vacancies ;  Public ;  Australian Capital Territory ;  158 non-null    object
#  20  Standard Error of Job Vacancies ;  Public ;  Australia ;                     158 non-null    object
# dtypes: datetime64[ns](1), object(20)
# memory usage: 30.5+ KB

# %%
# Clean column names into consistent, concise identifiers
#  - Standard errors -> prefix with "SE_" and suffix "_Public"
#  - Job Vacancies -> "<State>_Public"; handle Trend/Seasonal special cases
#  - Otherwise keep name unchanged
# This simplifies downstream selection and plotting.
def clean_col(name: str):
    name = str(name).strip()
    if name.startswith("Standard Error of Job Vacancies"):
        m = re.search(r"Standard Error of Job Vacancies\s*;\s*Public\s*;\s*(.*?)\s*;", name)
        state = m.group(1) if m else name
        return f"SE_{state}_Public"
    if name.startswith("Job Vacancies"):
        if "Seasonally Adjusted" in name:
            return "Australia_Public_Seasonal"
        if "Trend" in name:
            return "Australia_Public_Trend"
        m = re.search(r"Job Vacancies\s*;\s*Public\s*;\s*(.*?)\s*;", name)
        state = m.group(1) if m else name
        return f"{state}_Public"
    return name

# Apply the cleaner and inspect the new schema
df = df.rename(columns={c: clean_col(c) for c in df.columns})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    185 non-null    datetime64[ns]
#  1   New South Wales_Public                  161 non-null    object
#  2   Victoria_Public                         161 non-null    object
#  3   Queensland_Public                       162 non-null    object
#  4   South Australia_Public                  162 non-null    object
#  5   Western Australia_Public                158 non-null    object
#  6   Tasmania_Public                         162 non-null    object
#  7   Northern Territory_Public               162 non-null    object
#  8   Australian Capital Territory_Public     162 non-null    object
#  9   Australia_Public                        180 non-null    object
#  10  Australia_Public                        180 non-null    object
#  11  Australia_Public                        180 non-null    object
#  12  SE_New South Wales_Public               157 non-null    object
#  13  SE_Victoria_Public                      157 non-null    object
#  14  SE_Queensland_Public                    158 non-null    object
#  15  SE_South Australia_Public               158 non-null    object
#  16  SE_Western Australia_Public             154 non-null    object
#  17  SE_Tasmania_Public                      158 non-null    object
#  18  SE_Northern Territory_Public            158 non-null    object
#  19  SE_Australian Capital Territory_Public  158 non-null    object
#  20  SE_Australia_Public                     158 non-null    object
# dtypes: datetime64[ns](1), object(20)
# memory usage: 30.5+ KB

# %%
# Remove any duplicated columns that resulted from the raw sheet structure
# Keep the first occurrence and copy to avoid chained-assignment warnings
df = df.loc[:, ~df.columns.duplicated()].copy()
# Verify final columns and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 19 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Date                                    185 non-null    datetime64[ns]
#  1   New South Wales_Public                  161 non-null    object
#  2   Victoria_Public                         161 non-null    object
#  3   Queensland_Public                       162 non-null    object
#  4   South Australia_Public                  162 non-null    object
#  5   Western Australia_Public                158 non-null    object
#  6   Tasmania_Public                         162 non-null    object
#  7   Northern Territory_Public               162 non-null    object
#  8   Australian Capital Territory_Public     162 non-null    object
#  9   Australia_Public                        180 non-null    object
#  10  SE_New South Wales_Public               157 non-null    object
#  11  SE_Victoria_Public                      157 non-null    object
#  12  SE_Queensland_Public                    158 non-null    object
#  13  SE_South Australia_Public               158 non-null    object
#  14  SE_Western Australia_Public             154 non-null    object
#  15  SE_Tasmania_Public                      158 non-null    object
#  16  SE_Northern Territory_Public            158 non-null    object
#  17  SE_Australian Capital Territory_Public  158 non-null    object
#  18  SE_Australia_Public                     158 non-null    object
# dtypes: datetime64[ns](1), object(18)
# memory usage: 27.6+ KB

# %%
# Filter to the analysis period starting Nov 1983 and reset the index
df = df[df["Date"] >= "1983-11-01"].reset_index(drop=True)
# Sanity-check after filtering
df.head()
# Out:
#         Date New South Wales_Public Victoria_Public Queensland_Public  \
# 0 1983-11-15                    3.6             2.7                 1
# 1 1984-02-15                    3.7             2.9               1.4
# 2 1984-05-15                    3.5             2.5               1.3
# 3 1984-08-15                    5.1             2.2               1.3
# 4 1984-11-15                    NaN             2.6               1.3
#
#   South Australia_Public Western Australia_Public Tasmania_Public  \
# 0                    0.6                      0.8             0.4
# 1                    0.6                        0             0.6
# 2                    0.6                      0.4             0.4
# 3                    0.8                      1.1             0.5
# 4                    0.5                      NaN             0.5
#
#   Northern Territory_Public Australian Capital Territory_Public  \
# 0                       0.2                                 0.9
# 1                       0.2                                   1
# 2                       0.2                                   1
# 3                       0.3                                   1
# 4                       0.3                                 1.3
#
#   Australia_Public SE_New South Wales_Public SE_Victoria_Public  \
# 0             10.2                       NaN                NaN
# 1             10.4                       NaN                NaN
# 2              9.9                       NaN                NaN
# 3             12.3                       NaN                NaN
# 4             14.1                       NaN                0.2
#
#   SE_Queensland_Public SE_South Australia_Public SE_Western Australia_Public  \
# 0                  NaN                       NaN                         NaN
# 1                  NaN                       NaN                         NaN
# 2                  NaN                       NaN                         NaN
# 3                  NaN                       NaN                         NaN
# 4                  0.1                       0.1                         NaN
#
#   SE_Tasmania_Public SE_Northern Territory_Public  \
# 0                NaN                          NaN
# 1                NaN                          NaN
# 2                NaN                          NaN
# 3                NaN                          NaN
# 4                0.1                          0.1
#
#   SE_Australian Capital Territory_Public SE_Australia_Public
# 0                                    NaN                 NaN
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                                    NaN                 NaN
# 4                                    0.1                 2.1

# %%
# Split into two DataFrames:
#  - vac_df: vacancy values (non-SE columns)
#  - se_df: standard error columns with Date
se_cols = [c for c in df.columns if c.startswith("SE_")]
vac_cols =  [c for c in df.columns if c not in se_cols and c != "Series ID" and c != "Unit"]
vac_df = df[vac_cols].copy()
se_df = pd.concat([df[["Date"]], df[se_cols]], axis=1)

# %%
# Confirm schema for vacancy values (pre-conversion)
vac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Date                                 167 non-null    datetime64[ns]
#  1   New South Wales_Public               161 non-null    object
#  2   Victoria_Public                      161 non-null    object
#  3   Queensland_Public                    162 non-null    object
#  4   South Australia_Public               162 non-null    object
#  5   Western Australia_Public             158 non-null    object
#  6   Tasmania_Public                      162 non-null    object
#  7   Northern Territory_Public            162 non-null    object
#  8   Australian Capital Territory_Public  162 non-null    object
#  9   Australia_Public                     162 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 13.2+ KB

# %%
# Convert numeric-like columns from object to float for both frames
for frame in (vac_df, se_df):
    num_cols = frame.columns.drop("Date")
    for col in num_cols:
        frame[col] = pd.to_numeric(frame[col], errors="coerce")

# %%
# Save cleaned wide-form datasets to disk
vac_path = "../data/actual/preprocessed/public_vacancies_clean.csv"
se_path = "../data/actual/preprocessed/public_vacancies_standard_error.csv"
vac_df.to_csv(vac_path, index=False)
se_df.to_csv(se_path, index=False)

# %%
# Convert wide-form vacancies into a tidy long-form table
vac_long = vac_df.melt(id_vars="Date", var_name="Region", value_name="Vacancies_thousands")
# Persist long-form to CSV for downstream viz/analysis
vac_long_path = "../data/actual/preprocessed/public_vacancies_clean_long.csv"
vac_long.to_csv(vac_long_path, index=False)

# %%
# Reload the saved CSVs to verify outputs on disk
#  - data: wide-form vacancies
#  - se_data: standard errors (wide-form)
#  - data3: long-form vacancies
data = pd.read_csv(vac_path)
se_data = pd.read_csv(se_path)
data3 = pd.read_csv(vac_long_path)

# %%
# Baseline missingness summary (counts per column) before interpolation
data.isna().sum()
# Out:
# Date                                   0
# New South Wales_Public                 6
# Victoria_Public                        6
# Queensland_Public                      5
# South Australia_Public                 5
# Western Australia_Public               9
# Tasmania_Public                        5
# Northern Territory_Public              5
# Australian Capital Territory_Public    5
# Australia_Public                       5
# dtype: int64

# %%
# Column we require to be non-null while others are all null
keep_col = "Date"

# Build a boolean mask for rows where:
#  - every column EXCEPT `keep_col` is null
#  - and `keep_col` itself is non-null
mask = data.loc[:, data.columns != keep_col].isna().all(axis=1) & data[keep_col].notna()

# Preview the rows that match this condition (view only, no mutation)
rows = data.loc[mask]
rows
# Out:
#            Date  New South Wales_Public  Victoria_Public  Queensland_Public  \
# 99   2008-08-15                     NaN              NaN                NaN
# 100  2008-11-15                     NaN              NaN                NaN
# 101  2009-02-15                     NaN              NaN                NaN
# 102  2009-05-15                     NaN              NaN                NaN
# 103  2009-08-15                     NaN              NaN                NaN
#
#      South Australia_Public  Western Australia_Public  Tasmania_Public  \
# 99                      NaN                       NaN              NaN
# 100                     NaN                       NaN              NaN
# 101                     NaN                       NaN              NaN
# 102                     NaN                       NaN              NaN
# 103                     NaN                       NaN              NaN
#
#      Northern Territory_Public  Australian Capital Territory_Public  \
# 99                         NaN                                  NaN
# 100                        NaN                                  NaN
# 101                        NaN                                  NaN
# 102                        NaN                                  NaN
# 103                        NaN                                  NaN
#
#      Australia_Public
# 99                NaN
# 100               NaN
# 101               NaN
# 102               NaN
# 103               NaN

# %%
# Reuse the mask to identify rows to drop
mask = data.loc[:, data.columns != keep_col].isna().all(axis=1) & df[keep_col].notna()

# Count rows that satisfy the condition (for logging)
num_to_drop = int(mask.sum())

# Keep only rows that DO NOT match the mask (this drops the flagged rows)
data = data.loc[~mask].copy()

print(f"Dropped {num_to_drop} rows; new shape: {df.shape}")
# Out:
# Dropped 5 rows; new shape: (167, 19)

# %%
# Column we require to be non-null while others are all null
keep_col = "Date"

# Build a boolean mask for rows where:
#  - every column EXCEPT `keep_col` is null
#  - and `keep_col` itself is non-null
mask = data.loc[:, data.columns != keep_col].isna().all(axis=1) & data[keep_col].notna()

# Preview the rows that match this condition (view only, no mutation)
rows = data.loc[mask]
rows
# Out:
# Empty DataFrame
# Columns: [Date, New South Wales_Public, Victoria_Public, Queensland_Public, South Australia_Public, Western Australia_Public, Tasmania_Public, Northern Territory_Public, Australian Capital Territory_Public, Australia_Public]
# Index: []

# %%
data.isnull().sum()
# Out:
# Date                                   0
# New South Wales_Public                 1
# Victoria_Public                        1
# Queensland_Public                      0
# South Australia_Public                 0
# Western Australia_Public               4
# Tasmania_Public                        0
# Northern Territory_Public              0
# Australian Capital Territory_Public    0
# Australia_Public                       0
# dtype: int64

# %%
# Inspect any rows that still contain at least one null value
rows_with_any_nulls = data[data.isna().any(axis=1)]
rows_with_any_nulls
# Out:
#           Date  New South Wales_Public  Victoria_Public  Queensland_Public  \
# 4   1984-11-15                     NaN              2.6                1.3
# 6   1985-05-15                     5.5              3.3                1.4
# 7   1985-08-15                     6.7              3.9                1.1
# 17  1988-02-15                     7.8              NaN                2.0
#
#     South Australia_Public  Western Australia_Public  Tasmania_Public  \
# 4                      0.5                       NaN              0.5
# 6                      0.5                       NaN              0.7
# 7                      0.8                       NaN              0.4
# 17                     0.6                       NaN              0.5
#
#     Northern Territory_Public  Australian Capital Territory_Public  \
# 4                         0.3                                  1.3
# 6                         0.3                                  1.5
# 7                         0.2                                  1.5
# 17                        0.3                                  1.6
#
#     Australia_Public
# 4               14.1
# 6               14.9
# 7               16.6
# 17              17.6

# %%
# Attempt a simple linear interpolation over time for numeric gaps.
# Note: For object dtypes, call data.infer_objects(copy=False) before interpolating.
data = data.interpolate(method="linear", inplace=False)
# Out:
# C:\Users\rashe\AppData\Local\Temp\ipykernel_33668\1566431713.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data = data.interpolate(method="linear", inplace=False)

# %%
data.isna().sum()
# Out:
# Date                                   0
# New South Wales_Public                 0
# Victoria_Public                        0
# Queensland_Public                      0
# South Australia_Public                 0
# Western Australia_Public               0
# Tasmania_Public                        0
# Northern Territory_Public              0
# Australian Capital Territory_Public    0
# Australia_Public                       0
# dtype: int64

# %%
data.to_csv(vac_path, index=False)
