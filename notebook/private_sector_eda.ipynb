# %%
# Imports: regex utilities, pandas, and pathlib for file paths
import re
import pandas as pd
from pathlib import Path

# %%
# Source Excel file path for private sector vacancies
file_path = Path('../data/Actual/raw/private_sector.xlsx')

# %%
# Load the raw worksheet into a DataFrame
#   - sheet_name: source tab
#   - header: first row contains column names
df = pd.read_excel(file_path, sheet_name="Data1", header=0)

# %%
# Quick peek at the first 15 rows to inspect header/data lines
df.head(15)
# Out:
#              Unnamed: 0 Job Vacancies ;  Private ;  New South Wales ;  \
# 0                  Unit                                           000
# 1           Series Type                                      Original
# 2             Data Type                                         STOCK
# 3             Frequency                                       Quarter
# 4      Collection Month                                             2
# 5          Series Start                           1983-11-15 00:00:00
# 6            Series End                           2025-05-15 00:00:00
# 7               No. Obs                                           167
# 8             Series ID                                      A590702K
# 9   1979-05-15 00:00:00                                           NaN
# 10  1979-08-15 00:00:00                                           NaN
# 11  1979-11-15 00:00:00                                           NaN
# 12  1980-02-15 00:00:00                                           NaN
# 13  1980-05-15 00:00:00                                           NaN
# 14  1980-08-15 00:00:00                                           NaN
#
#    Job Vacancies ;  Private ;  Victoria ;  \
# 0                                     000
# 1                                Original
# 2                                   STOCK
# 3                                 Quarter
# 4                                       2
# 5                     1983-11-15 00:00:00
# 6                     2025-05-15 00:00:00
# 7                                     167
# 8                                A590720R
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#    Job Vacancies ;  Private ;  Queensland ;  \
# 0                                       000
# 1                                  Original
# 2                                     STOCK
# 3                                   Quarter
# 4                                         2
# 5                       1983-11-15 00:00:00
# 6                       2025-05-15 00:00:00
# 7                                       167
# 8                                  A590738L
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
#
#    Job Vacancies ;  Private ;  South Australia ;  \
# 0                                            000
# 1                                       Original
# 2                                          STOCK
# 3                                        Quarter
# 4                                              2
# 5                            1983-11-15 00:00:00
# 6                            2025-05-15 00:00:00
# 7                                            167
# 8                                       A590756T
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
#
#    Job Vacancies ;  Private ;  Western Australia ;  \
# 0                                              000
# 1                                         Original
# 2                                            STOCK
# 3                                          Quarter
# 4                                                2
# 5                              1983-11-15 00:00:00
# 6                              2025-05-15 00:00:00
# 7                                              167
# 8                                         A590774W
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
#
#    Job Vacancies ;  Private ;  Tasmania ;  \
# 0                                     000
# 1                                Original
# 2                                   STOCK
# 3                                 Quarter
# 4                                       2
# 5                     1983-11-15 00:00:00
# 6                     2025-05-15 00:00:00
# 7                                     167
# 8                                A590792A
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
#
#    Job Vacancies ;  Private ;  Northern Territory ;  \
# 0                                               000
# 1                                          Original
# 2                                             STOCK
# 3                                           Quarter
# 4                                                 2
# 5                               1983-11-15 00:00:00
# 6                               2025-05-15 00:00:00
# 7                                               167
# 8                                          A590810V
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
#
#    Job Vacancies ;  Private ;  Australian Capital Territory ;  \
# 0                                                 000
# 1                                            Original
# 2                                               STOCK
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590828T
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Job Vacancies ;  Private ;  Australia ;  ...  \
# 0                                      000  ...
# 1                                 Original  ...
# 2                                    STOCK  ...
# 3                                  Quarter  ...
# 4                                        2  ...
# 5                      1979-05-15 00:00:00  ...
# 6                      2025-05-15 00:00:00  ...
# 7                                      185  ...
# 8                                 A590684T  ...
# 9                                     28.6  ...
# 10                                    28.6  ...
# 11                                    24.6  ...
# 12                                    27.3  ...
# 13                                    21.7  ...
# 14                                    22.5  ...
#
#    Job Vacancies ;  Private ;  Australia ;.2  \
# 0                                        000
# 1                                      Trend
# 2                                      STOCK
# 3                                    Quarter
# 4                                          2
# 5                        1979-05-15 00:00:00
# 6                        2025-05-15 00:00:00
# 7                                        185
# 8                                   A590688A
# 9                                       31.2
# 10                                      28.6
# 11                                      25.9
# 12                                      23.9
# 13                                      23.7
# 14                                      24.3
#
#    Standard Error of Job Vacancies ;  Private ;  New South Wales ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590703L
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Victoria ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590721T
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Queensland ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590739R
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  South Australia ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590757V
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Western Australia ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590775X
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Tasmania ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590793C
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Northern Territory ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590811W
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Australian Capital Territory ;  \
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1983-11-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 167
# 8                                            A590829V
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#    Standard Error of Job Vacancies ;  Private ;  Australia ;
# 0                                                 000
# 1                                            Original
# 2                                               RATIO
# 3                                             Quarter
# 4                                                   2
# 5                                 1979-05-15 00:00:00
# 6                                 2025-05-15 00:00:00
# 7                                                 185
# 8                                            A590685V
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
# [15 rows x 21 columns]

# %%
# Drop the first 9 rows (metadata in the sheet) and reset the index
df = df.iloc[9:].reset_index(drop=True)

# %%
# Inspect column names, dtypes, and non-null counts after trimming header rows
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 21 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Unnamed: 0                                                                    185 non-null    object
#  1   Job Vacancies ;  Private ;  New South Wales ;                                 162 non-null    object
#  2   Job Vacancies ;  Private ;  Victoria ;                                        162 non-null    object
#  3   Job Vacancies ;  Private ;  Queensland ;                                      162 non-null    object
#  4   Job Vacancies ;  Private ;  South Australia ;                                 162 non-null    object
#  5   Job Vacancies ;  Private ;  Western Australia ;                               161 non-null    object
#  6   Job Vacancies ;  Private ;  Tasmania ;                                        155 non-null    object
#  7   Job Vacancies ;  Private ;  Northern Territory ;                              156 non-null    object
#  8   Job Vacancies ;  Private ;  Australian Capital Territory ;                    151 non-null    object
#  9   Job Vacancies ;  Private ;  Australia ;                                       180 non-null    object
#  10  Job Vacancies ;  Private ;  Australia ;.1                                     180 non-null    object
#  11  Job Vacancies ;  Private ;  Australia ;.2                                     180 non-null    object
#  12  Standard Error of Job Vacancies ;  Private ;  New South Wales ;               158 non-null    object
#  13  Standard Error of Job Vacancies ;  Private ;  Victoria ;                      158 non-null    object
#  14  Standard Error of Job Vacancies ;  Private ;  Queensland ;                    158 non-null    object
#  15  Standard Error of Job Vacancies ;  Private ;  South Australia ;               158 non-null    object
#  16  Standard Error of Job Vacancies ;  Private ;  Western Australia ;             157 non-null    object
#  17  Standard Error of Job Vacancies ;  Private ;  Tasmania ;                      151 non-null    object
#  18  Standard Error of Job Vacancies ;  Private ;  Northern Territory ;            152 non-null    object
#  19  Standard Error of Job Vacancies ;  Private ;  Australian Capital Territory ;  147 non-null    object
#  20  Standard Error of Job Vacancies ;  Private ;  Australia ;                     158 non-null    object
# dtypes: object(21)
# memory usage: 30.5+ KB

# %%
# Rename the first column to a canonical "Date" and parse as datetime
time_col = df.columns[0]
df = df.rename(columns={time_col: "Date"})
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# %%
# Validate that "Date" is datetime and review missingness after parsing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 21 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Date                                                                          185 non-null    datetime64[ns]
#  1   Job Vacancies ;  Private ;  New South Wales ;                                 162 non-null    object
#  2   Job Vacancies ;  Private ;  Victoria ;                                        162 non-null    object
#  3   Job Vacancies ;  Private ;  Queensland ;                                      162 non-null    object
#  4   Job Vacancies ;  Private ;  South Australia ;                                 162 non-null    object
#  5   Job Vacancies ;  Private ;  Western Australia ;                               161 non-null    object
#  6   Job Vacancies ;  Private ;  Tasmania ;                                        155 non-null    object
#  7   Job Vacancies ;  Private ;  Northern Territory ;                              156 non-null    object
#  8   Job Vacancies ;  Private ;  Australian Capital Territory ;                    151 non-null    object
#  9   Job Vacancies ;  Private ;  Australia ;                                       180 non-null    object
#  10  Job Vacancies ;  Private ;  Australia ;.1                                     180 non-null    object
#  11  Job Vacancies ;  Private ;  Australia ;.2                                     180 non-null    object
#  12  Standard Error of Job Vacancies ;  Private ;  New South Wales ;               158 non-null    object
#  13  Standard Error of Job Vacancies ;  Private ;  Victoria ;                      158 non-null    object
#  14  Standard Error of Job Vacancies ;  Private ;  Queensland ;                    158 non-null    object
#  15  Standard Error of Job Vacancies ;  Private ;  South Australia ;               158 non-null    object
#  16  Standard Error of Job Vacancies ;  Private ;  Western Australia ;             157 non-null    object
#  17  Standard Error of Job Vacancies ;  Private ;  Tasmania ;                      151 non-null    object
#  18  Standard Error of Job Vacancies ;  Private ;  Northern Territory ;            152 non-null    object
#  19  Standard Error of Job Vacancies ;  Private ;  Australian Capital Territory ;  147 non-null    object
#  20  Standard Error of Job Vacancies ;  Private ;  Australia ;                     158 non-null    object
# dtypes: datetime64[ns](1), object(20)
# memory usage: 30.5+ KB

# %%
# Clean column names into consistent, concise identifiers
#  - Standard errors -> prefix with "SE_" and suffix "_Private"
#  - Job Vacancies -> "<State>_Private"; handle Trend/Seasonal special cases
#  - Otherwise keep name unchanged
# This simplifies downstream selection and plotting.
def clean_col(name: str):
    name = str(name).strip()
    if name.startswith("Standard Error of Job Vacancies"):
        m = re.search(r"Standard Error of Job Vacancies\s*;\s*Private\s*;\s*(.*?)\s*;", name)
        state = m.group(1) if m else name
        return f"SE_{state}_Private"
    if name.startswith("Job Vacancies"):
        if "Seasonally Adjusted" in name:
            return "Australia_Private_Seasonal"
        if "Trend" in name:
            return "Australia_Private_Trend"
        m = re.search(r"Job Vacancies\s*;\s*Private\s*;\s*(.*?)\s*;", name)
        state = m.group(1) if m else name
        return f"{state}_Private"
    return name

# Apply the cleaner and inspect the new schema
df = df.rename(columns={c: clean_col(c) for c in df.columns})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     185 non-null    datetime64[ns]
#  1   New South Wales_Private                  162 non-null    object
#  2   Victoria_Private                         162 non-null    object
#  3   Queensland_Private                       162 non-null    object
#  4   South Australia_Private                  162 non-null    object
#  5   Western Australia_Private                161 non-null    object
#  6   Tasmania_Private                         155 non-null    object
#  7   Northern Territory_Private               156 non-null    object
#  8   Australian Capital Territory_Private     151 non-null    object
#  9   Australia_Private                        180 non-null    object
#  10  Australia_Private                        180 non-null    object
#  11  Australia_Private                        180 non-null    object
#  12  SE_New South Wales_Private               158 non-null    object
#  13  SE_Victoria_Private                      158 non-null    object
#  14  SE_Queensland_Private                    158 non-null    object
#  15  SE_South Australia_Private               158 non-null    object
#  16  SE_Western Australia_Private             157 non-null    object
#  17  SE_Tasmania_Private                      151 non-null    object
#  18  SE_Northern Territory_Private            152 non-null    object
#  19  SE_Australian Capital Territory_Private  147 non-null    object
#  20  SE_Australia_Private                     158 non-null    object
# dtypes: datetime64[ns](1), object(20)
# memory usage: 30.5+ KB

# %%
# Remove any duplicated columns that resulted from the raw sheet structure
# Keep the first occurrence and copy to avoid chained-assignment warnings
df = df.loc[:, ~df.columns.duplicated()].copy()
# Verify final columns and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     185 non-null    datetime64[ns]
#  1   New South Wales_Private                  162 non-null    object
#  2   Victoria_Private                         162 non-null    object
#  3   Queensland_Private                       162 non-null    object
#  4   South Australia_Private                  162 non-null    object
#  5   Western Australia_Private                161 non-null    object
#  6   Tasmania_Private                         155 non-null    object
#  7   Northern Territory_Private               156 non-null    object
#  8   Australian Capital Territory_Private     151 non-null    object
#  9   Australia_Private                        180 non-null    object
#  10  SE_New South Wales_Private               158 non-null    object
#  11  SE_Victoria_Private                      158 non-null    object
#  12  SE_Queensland_Private                    158 non-null    object
#  13  SE_South Australia_Private               158 non-null    object
#  14  SE_Western Australia_Private             157 non-null    object
#  15  SE_Tasmania_Private                      151 non-null    object
#  16  SE_Northern Territory_Private            152 non-null    object
#  17  SE_Australian Capital Territory_Private  147 non-null    object
#  18  SE_Australia_Private                     158 non-null    object
# dtypes: datetime64[ns](1), object(18)
# memory usage: 27.6+ KB

# %%
# Quick preview to confirm column order and first few rows after cleaning
df.head()
# Out:
#         Date New South Wales_Private Victoria_Private Queensland_Private  \
# 0 1979-05-15                     NaN              NaN                NaN
# 1 1979-08-15                     NaN              NaN                NaN
# 2 1979-11-15                     NaN              NaN                NaN
# 3 1980-02-15                     NaN              NaN                NaN
# 4 1980-05-15                     NaN              NaN                NaN
#
#   South Australia_Private Western Australia_Private Tasmania_Private  \
# 0                     NaN                       NaN              NaN
# 1                     NaN                       NaN              NaN
# 2                     NaN                       NaN              NaN
# 3                     NaN                       NaN              NaN
# 4                     NaN                       NaN              NaN
#
#   Northern Territory_Private Australian Capital Territory_Private  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
# 3                        NaN                                  NaN
# 4                        NaN                                  NaN
#
#   Australia_Private SE_New South Wales_Private SE_Victoria_Private  \
# 0              28.6                        NaN                 NaN
# 1              28.6                        NaN                 NaN
# 2              24.6                        NaN                 NaN
# 3              27.3                        NaN                 NaN
# 4              21.7                        NaN                 NaN
#
#   SE_Queensland_Private SE_South Australia_Private  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
#
#   SE_Western Australia_Private SE_Tasmania_Private  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          NaN                 NaN
#
#   SE_Northern Territory_Private SE_Australian Capital Territory_Private  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
#
#   SE_Australia_Private
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# Filter to the analysis period starting Nov 1983 and reset the index
df = df[df["Date"] >= "1983-11-01"].reset_index(drop=True)
# Sanity-check after filtering
df.head()
# Out:
#         Date New South Wales_Private Victoria_Private Queensland_Private  \
# 0 1983-11-15                      10              4.9                  4
# 1 1984-02-15                    20.8              9.5                  4
# 2 1984-05-15                    14.6              8.4                3.7
# 3 1984-08-15                    16.2              7.3                3.7
# 4 1984-11-15                    11.6             11.3                3.9
#
#   South Australia_Private Western Australia_Private Tasmania_Private  \
# 0                       2                       3.5              0.5
# 1                     3.6                         0                0
# 2                     2.3                         0                0
# 3                     2.5                       2.3              0.4
# 4                     2.2                       3.5              NaN
#
#   Northern Territory_Private Australian Capital Territory_Private  \
# 0                        0.3                                  0.5
# 1                        0.3                                  0.4
# 2                        0.5                                  0.7
# 3                        0.4                                  0.3
# 4                        0.6                                  NaN
#
#   Australia_Private SE_New South Wales_Private SE_Victoria_Private  \
# 0              25.8                        NaN                 NaN
# 1              38.7                        NaN                 NaN
# 2              30.2                        NaN                 NaN
# 3                33                        NaN                 NaN
# 4              33.6                        2.3                   2
#
#   SE_Queensland_Private SE_South Australia_Private  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   0.9                        0.4
#
#   SE_Western Australia_Private SE_Tasmania_Private  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          0.9                 NaN
#
#   SE_Northern Territory_Private SE_Australian Capital Territory_Private  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           0.1                                     NaN
#
#   SE_Australia_Private
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  3.3

# %%
# Count missing values per column to identify problematic series
df.isna().sum()
# Out:
# Date                                        0
# New South Wales_Private                     5
# Victoria_Private                            5
# Queensland_Private                          5
# South Australia_Private                     5
# Western Australia_Private                   6
# Tasmania_Private                           12
# Northern Territory_Private                 11
# Australian Capital Territory_Private       16
# Australia_Private                           5
# SE_New South Wales_Private                  9
# SE_Victoria_Private                         9
# SE_Queensland_Private                       9
# SE_South Australia_Private                  9
# SE_Western Australia_Private               10
# SE_Tasmania_Private                        16
# SE_Northern Territory_Private              15
# SE_Australian Capital Territory_Private    20
# SE_Australia_Private                        9
# dtype: int64

# %%
# Column we require to be non-null while others are all null
keep_col = "Date"

# Build a boolean mask for rows where:
#  - every column EXCEPT `keep_col` is null
#  - and `keep_col` itself is non-null
mask = df.loc[:, df.columns != keep_col].isna().all(axis=1) & df[keep_col].notna()

# Preview the rows that match this condition (view only, no mutation)
rows = df.loc[mask]
rows
# Out:
#           Date New South Wales_Private Victoria_Private Queensland_Private  \
# 99  2008-08-15                     NaN              NaN                NaN
# 100 2008-11-15                     NaN              NaN                NaN
# 101 2009-02-15                     NaN              NaN                NaN
# 102 2009-05-15                     NaN              NaN                NaN
# 103 2009-08-15                     NaN              NaN                NaN
#
#     South Australia_Private Western Australia_Private Tasmania_Private  \
# 99                      NaN                       NaN              NaN
# 100                     NaN                       NaN              NaN
# 101                     NaN                       NaN              NaN
# 102                     NaN                       NaN              NaN
# 103                     NaN                       NaN              NaN
#
#     Northern Territory_Private Australian Capital Territory_Private  \
# 99                         NaN                                  NaN
# 100                        NaN                                  NaN
# 101                        NaN                                  NaN
# 102                        NaN                                  NaN
# 103                        NaN                                  NaN
#
#     Australia_Private SE_New South Wales_Private SE_Victoria_Private  \
# 99                NaN                        NaN                 NaN
# 100               NaN                        NaN                 NaN
# 101               NaN                        NaN                 NaN
# 102               NaN                        NaN                 NaN
# 103               NaN                        NaN                 NaN
#
#     SE_Queensland_Private SE_South Australia_Private  \
# 99                    NaN                        NaN
# 100                   NaN                        NaN
# 101                   NaN                        NaN
# 102                   NaN                        NaN
# 103                   NaN                        NaN
#
#     SE_Western Australia_Private SE_Tasmania_Private  \
# 99                           NaN                 NaN
# 100                          NaN                 NaN
# 101                          NaN                 NaN
# 102                          NaN                 NaN
# 103                          NaN                 NaN
#
#     SE_Northern Territory_Private SE_Australian Capital Territory_Private  \
# 99                            NaN                                     NaN
# 100                           NaN                                     NaN
# 101                           NaN                                     NaN
# 102                           NaN                                     NaN
# 103                           NaN                                     NaN
#
#     SE_Australia_Private
# 99                   NaN
# 100                  NaN
# 101                  NaN
# 102                  NaN
# 103                  NaN

# %%
# Reuse the mask to identify rows to drop
mask = df.loc[:, df.columns != keep_col].isna().all(axis=1) & df[keep_col].notna()

# Count rows that satisfy the condition (for logging)
num_to_drop = int(mask.sum())

# Keep only rows that DO NOT match the mask (this drops the flagged rows)
df = df.loc[~mask].copy()

print(f"Dropped {num_to_drop} rows; new shape: {df.shape}")
# Out:
# Dropped 5 rows; new shape: (162, 19)

# %%
# Re-check missingness after dropping the fully-null rows (except Date)
df.isna().sum()
# Out:
# Date                                        0
# New South Wales_Private                     0
# Victoria_Private                            0
# Queensland_Private                          0
# South Australia_Private                     0
# Western Australia_Private                   1
# Tasmania_Private                            7
# Northern Territory_Private                  6
# Australian Capital Territory_Private       11
# Australia_Private                           0
# SE_New South Wales_Private                  4
# SE_Victoria_Private                         4
# SE_Queensland_Private                       4
# SE_South Australia_Private                  4
# SE_Western Australia_Private                5
# SE_Tasmania_Private                        11
# SE_Northern Territory_Private              10
# SE_Australian Capital Territory_Private    15
# SE_Australia_Private                        4
# dtype: int64

# %%
# Inspect any rows that still contain at least one null value
rows_with_any_nulls = df[df.isna().any(axis=1)]
rows_with_any_nulls
# Out:
#          Date New South Wales_Private Victoria_Private Queensland_Private  \
# 0  1983-11-15                      10              4.9                  4
# 1  1984-02-15                    20.8              9.5                  4
# 2  1984-05-15                    14.6              8.4                3.7
# 3  1984-08-15                    16.2              7.3                3.7
# 4  1984-11-15                    11.6             11.3                3.9
# 7  1985-08-15                    12.2             17.6                7.5
# 9  1986-02-15                    19.2             17.1                8.5
# 11 1986-08-15                    13.2             12.8                4.2
# 12 1986-11-15                    17.3             12.2                5.4
# 13 1987-02-15                    20.5             18.5                5.8
# 14 1987-05-15                    16.6             18.1                3.7
# 15 1987-08-15                    20.2             16.9                5.4
# 16 1987-11-15                    21.8             10.7                3.5
# 17 1988-02-15                    23.4             17.1                6.1
# 18 1988-05-15                    20.3             19.3                6.4
# 19 1988-08-15                    29.8             18.4                7.3
#
#    South Australia_Private Western Australia_Private Tasmania_Private  \
# 0                        2                       3.5              0.5
# 1                      3.6                         0                0
# 2                      2.3                         0                0
# 3                      2.5                       2.3              0.4
# 4                      2.2                       3.5              NaN
# 7                      3.8                       NaN              0.6
# 9                      3.3                       3.7              1.3
# 11                     4.9                       4.7              0.5
# 12                     3.8                         4              NaN
# 13                     4.4                       5.9              NaN
# 14                     3.6                       5.4              NaN
# 15                     3.4                         5              NaN
# 16                     3.1                       6.3              0.7
# 17                     3.9                       5.9              NaN
# 18                     3.3                       4.7              NaN
# 19                       3                       4.3              0.2
#
#    Northern Territory_Private Australian Capital Territory_Private  \
# 0                         0.3                                  0.5
# 1                         0.3                                  0.4
# 2                         0.5                                  0.7
# 3                         0.4                                  0.3
# 4                         0.6                                  NaN
# 7                         0.7                                  NaN
# 9                         0.7                                  NaN
# 11                        NaN                                  NaN
# 12                        NaN                                  NaN
# 13                        NaN                                  NaN
# 14                        0.6                                  0.4
# 15                        NaN                                  NaN
# 16                        NaN                                  NaN
# 17                        NaN                                  NaN
# 18                        0.5                                  NaN
# 19                        0.7                                  NaN
#
#    Australia_Private SE_New South Wales_Private SE_Victoria_Private  \
# 0               25.8                        NaN                 NaN
# 1               38.7                        NaN                 NaN
# 2               30.2                        NaN                 NaN
# 3                 33                        NaN                 NaN
# 4               33.6                        2.3                   2
# 7               46.9                        1.8                 2.3
# 9               54.8                        3.8                 2.5
# 11                42                        1.9                 2.2
# 12                45                        3.3                   2
# 13              57.6                        3.3                 2.8
# 14              49.6                        2.4                   3
# 15              52.5                          4                 3.3
# 16              47.9                        3.7                 1.7
# 17              58.3                        3.1                 2.4
# 18              55.5                        4.2                 3.3
# 19              64.6                        3.7                 3.2
#
#    SE_Queensland_Private SE_South Australia_Private  \
# 0                    NaN                        NaN
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    0.9                        0.4
# 7                    1.7                        0.7
# 9                    1.8                        0.6
# 11                   1.1                        1.2
# 12                   1.2                        0.7
# 13                   1.3                        0.8
# 14                   0.8                        1.1
# 15                   1.2                        0.6
# 16                   0.7                        0.6
# 17                   1.3                        0.8
# 18                   1.1                        0.8
# 19                   1.3                        0.5
#
#    SE_Western Australia_Private SE_Tasmania_Private  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           0.9                 NaN
# 7                           NaN                 0.1
# 9                           0.7                 0.2
# 11                          1.1                 0.1
# 12                          1.1                 NaN
# 13                          1.3                 NaN
# 14                          1.1                 NaN
# 15                          1.2                 NaN
# 16                          1.5                 0.2
# 17                          1.5                 NaN
# 18                          1.2                 NaN
# 19                          0.9                   0
#
#    SE_Northern Territory_Private SE_Australian Capital Territory_Private  \
# 0                            NaN                                     NaN
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            0.1                                     NaN
# 7                            0.2                                     NaN
# 9                            0.2                                     NaN
# 11                           NaN                                     NaN
# 12                           NaN                                     NaN
# 13                           NaN                                     NaN
# 14                           0.2                                     0.1
# 15                           NaN                                     NaN
# 16                           NaN                                     NaN
# 17                           NaN                                     NaN
# 18                           0.1                                     NaN
# 19                           0.2                                     NaN
#
#    SE_Australia_Private
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   3.3
# 7                   3.8
# 9                     5
# 11                  3.6
# 12                  4.2
# 13                  4.8
# 14                  4.2
# 15                  5.5
# 16                  4.4
# 17                  4.5
# 18                  5.6
# 19                  5.1

# %%
# Column-wise null counts again for reference
df.isna().sum()
# Out:
# Date                                        0
# New South Wales_Private                     0
# Victoria_Private                            0
# Queensland_Private                          0
# South Australia_Private                     0
# Western Australia_Private                   1
# Tasmania_Private                            7
# Northern Territory_Private                  6
# Australian Capital Territory_Private       11
# Australia_Private                           0
# SE_New South Wales_Private                  4
# SE_Victoria_Private                         4
# SE_Queensland_Private                       4
# SE_South Australia_Private                  4
# SE_Western Australia_Private                5
# SE_Tasmania_Private                        11
# SE_Northern Territory_Private              10
# SE_Australian Capital Territory_Private    15
# SE_Australia_Private                        4
# dtype: int64

# %%
# Final preview of cleaned data before splitting into value and SE tables
df.head()
# Out:
#         Date New South Wales_Private Victoria_Private Queensland_Private  \
# 0 1983-11-15                      10              4.9                  4
# 1 1984-02-15                    20.8              9.5                  4
# 2 1984-05-15                    14.6              8.4                3.7
# 3 1984-08-15                    16.2              7.3                3.7
# 4 1984-11-15                    11.6             11.3                3.9
#
#   South Australia_Private Western Australia_Private Tasmania_Private  \
# 0                       2                       3.5              0.5
# 1                     3.6                         0                0
# 2                     2.3                         0                0
# 3                     2.5                       2.3              0.4
# 4                     2.2                       3.5              NaN
#
#   Northern Territory_Private Australian Capital Territory_Private  \
# 0                        0.3                                  0.5
# 1                        0.3                                  0.4
# 2                        0.5                                  0.7
# 3                        0.4                                  0.3
# 4                        0.6                                  NaN
#
#   Australia_Private SE_New South Wales_Private SE_Victoria_Private  \
# 0              25.8                        NaN                 NaN
# 1              38.7                        NaN                 NaN
# 2              30.2                        NaN                 NaN
# 3                33                        NaN                 NaN
# 4              33.6                        2.3                   2
#
#   SE_Queensland_Private SE_South Australia_Private  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   0.9                        0.4
#
#   SE_Western Australia_Private SE_Tasmania_Private  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          0.9                 NaN
#
#   SE_Northern Territory_Private SE_Australian Capital Territory_Private  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           0.1                                     NaN
#
#   SE_Australia_Private
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  3.3

# %%
# Split into two DataFrames:
#  - vac_df: vacancy values (non-SE columns)
#  - se_df: standard error columns with Date
se_cols = [c for c in df.columns if c.startswith("SE_")]
vac_cols =  [c for c in df.columns if c not in se_cols and c != "Series ID" and c != "Unit"]
vac_df = df[vac_cols].copy()
se_df = pd.concat([df[["Date"]], df[se_cols]], axis=1)

# %%
# Confirm schema for vacancy values (pre-conversion)
vac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  162 non-null    datetime64[ns]
#  1   New South Wales_Private               162 non-null    object
#  2   Victoria_Private                      162 non-null    object
#  3   Queensland_Private                    162 non-null    object
#  4   South Australia_Private               162 non-null    object
#  5   Western Australia_Private             161 non-null    object
#  6   Tasmania_Private                      155 non-null    object
#  7   Northern Territory_Private            156 non-null    object
#  8   Australian Capital Territory_Private  151 non-null    object
#  9   Australia_Private                     162 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 13.9+ KB

# %%
# Preview vacancy values
vac_df.head()
# Out:
#         Date New South Wales_Private Victoria_Private Queensland_Private  \
# 0 1983-11-15                      10              4.9                  4
# 1 1984-02-15                    20.8              9.5                  4
# 2 1984-05-15                    14.6              8.4                3.7
# 3 1984-08-15                    16.2              7.3                3.7
# 4 1984-11-15                    11.6             11.3                3.9
#
#   South Australia_Private Western Australia_Private Tasmania_Private  \
# 0                       2                       3.5              0.5
# 1                     3.6                         0                0
# 2                     2.3                         0                0
# 3                     2.5                       2.3              0.4
# 4                     2.2                       3.5              NaN
#
#   Northern Territory_Private Australian Capital Territory_Private  \
# 0                        0.3                                  0.5
# 1                        0.3                                  0.4
# 2                        0.5                                  0.7
# 3                        0.4                                  0.3
# 4                        0.6                                  NaN
#
#   Australia_Private
# 0              25.8
# 1              38.7
# 2              30.2
# 3                33
# 4              33.6

# %%
# Preview standard error values
se_df.head()
# Out:
#         Date SE_New South Wales_Private SE_Victoria_Private  \
# 0 1983-11-15                        NaN                 NaN
# 1 1984-02-15                        NaN                 NaN
# 2 1984-05-15                        NaN                 NaN
# 3 1984-08-15                        NaN                 NaN
# 4 1984-11-15                        2.3                   2
#
#   SE_Queensland_Private SE_South Australia_Private  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   0.9                        0.4
#
#   SE_Western Australia_Private SE_Tasmania_Private  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
# 2                          NaN                 NaN
# 3                          NaN                 NaN
# 4                          0.9                 NaN
#
#   SE_Northern Territory_Private SE_Australian Capital Territory_Private  \
# 0                           NaN                                     NaN
# 1                           NaN                                     NaN
# 2                           NaN                                     NaN
# 3                           NaN                                     NaN
# 4                           0.1                                     NaN
#
#   SE_Australia_Private
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  3.3

# %%
# Convert numeric-like columns from object to float for both frames
for frame in (vac_df, se_df):
    num_cols = frame.columns.drop("Date")
    for col in num_cols:
        frame[col] = pd.to_numeric(frame[col], errors="coerce")

# %%
# Validate dtypes are now numeric for vacancy values
vac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Date                                  162 non-null    datetime64[ns]
#  1   New South Wales_Private               162 non-null    float64
#  2   Victoria_Private                      162 non-null    float64
#  3   Queensland_Private                    162 non-null    float64
#  4   South Australia_Private               162 non-null    float64
#  5   Western Australia_Private             161 non-null    float64
#  6   Tasmania_Private                      155 non-null    float64
#  7   Northern Territory_Private            156 non-null    float64
#  8   Australian Capital Territory_Private  151 non-null    float64
#  9   Australia_Private                     162 non-null    float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 13.9 KB

# %%
# Validate dtypes are now numeric for standard errors
se_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Date                                     162 non-null    datetime64[ns]
#  1   SE_New South Wales_Private               158 non-null    float64
#  2   SE_Victoria_Private                      158 non-null    float64
#  3   SE_Queensland_Private                    158 non-null    float64
#  4   SE_South Australia_Private               158 non-null    float64
#  5   SE_Western Australia_Private             157 non-null    float64
#  6   SE_Tasmania_Private                      151 non-null    float64
#  7   SE_Northern Territory_Private            152 non-null    float64
#  8   SE_Australian Capital Territory_Private  147 non-null    float64
#  9   SE_Australia_Private                     158 non-null    float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 13.9 KB

# %%
# Save cleaned wide-form datasets to disk
# Save cleaned wide-form datasets to disk
vac_path = "../data/actual/preprocessed/private_vacancies_clean.csv"
se_path = "../data/actual/preprocessed/private_vacancies_standard_error.csv"
vac_df.to_csv(vac_path, index=False)
se_df.to_csv(se_path, index=False)

# %%
# Convert wide-form vacancies into a tidy long-form table
vac_long = vac_df.melt(id_vars="Date", var_name="Region", value_name="Vacancies_thousands")

# Persist long-form to CSV for downstream viz/analysis
vac_long_path = "../data/actual/preprocessed/private_vacancies_clean_long.csv"
vac_long.to_csv(vac_long_path, index=False)

# %%
# Reload the saved CSVs to verify outputs on disk
#  - data: wide-form vacancies
#  - se_data: standard errors (wide-form)
#  - data3: long-form vacancies
data = pd.read_csv(vac_path)
se_data = pd.read_csv(se_path)
data3 = pd.read_csv(vac_long_path)

# %%
# Baseline missingness summary (counts per column) before interpolation
data.isna().sum()
# Out:
# Date                                     0
# New South Wales_Private                  0
# Victoria_Private                         0
# Queensland_Private                       0
# South Australia_Private                  0
# Western Australia_Private                1
# Tasmania_Private                         7
# Northern Territory_Private               6
# Australian Capital Territory_Private    11
# Australia_Private                        0
# dtype: int64

# %%
# Attempt a simple linear interpolation over time for numeric gaps.
# Note: For object dtypes, call data.infer_objects(copy=False) before interpolating.
data.interpolate(method="linear", inplace=False)
# Out:
# C:\Users\rashe\AppData\Local\Temp\ipykernel_30408\1278604908.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate(method="linear", inplace=False)
#            Date  New South Wales_Private  Victoria_Private  \
# 0    1983-11-15                     10.0               4.9
# 1    1984-02-15                     20.8               9.5
# 2    1984-05-15                     14.6               8.4
# 3    1984-08-15                     16.2               7.3
# 4    1984-11-15                     11.6              11.3
# ..          ...                      ...               ...
# 157  2024-05-15                     91.5              78.1
# 158  2024-08-15                     90.3              75.2
# 159  2024-11-15                     93.0              72.7
# 160  2025-02-15                     89.6              67.1
# 161  2025-05-15                     86.3              72.1
#
#      Queensland_Private  South Australia_Private  Western Australia_Private  \
# 0                   4.0                      2.0                        3.5
# 1                   4.0                      3.6                        0.0
# 2                   3.7                      2.3                        0.0
# 3                   3.7                      2.5                        2.3
# 4                   3.9                      2.2                        3.5
# ..                  ...                      ...                        ...
# 157                60.1                     18.6                       38.4
# 158                61.2                     16.3                       38.3
# 159                70.0                     20.2                       38.9
# 160                63.1                     18.1                       40.6
# 161                64.1                     19.6                       37.9
#
#      Tasmania_Private  Northern Territory_Private  \
# 0                 0.5                         0.3
# 1                 0.0                         0.3
# 2                 0.0                         0.5
# 3                 0.4                         0.4
# 4                 0.5                         0.6
# ..                ...                         ...
# 157               5.3                         4.4
# 158               5.2                         4.1
# 159               5.4                         4.7
# 160               4.3                         4.4
# 161               4.5                         3.8
#
#      Australian Capital Territory_Private  Australia_Private
# 0                                     0.5               25.8
# 1                                     0.4               38.7
# 2                                     0.7               30.2
# 3                                     0.3               33.0
# 4                                     0.8               33.6
# ..                                    ...                ...
# 157                                   5.8              302.1
# 158                                   5.8              296.3
# 159                                   6.8              311.6
# 160                                   5.1              292.5
# 161                                   5.8              294.1
#
# [162 rows x 10 columns]

# %%
# Check remaining missing values after any interpolation/transforms
data.isna().sum()
# Out:
# Date                                     0
# New South Wales_Private                  0
# Victoria_Private                         0
# Queensland_Private                       0
# South Australia_Private                  0
# Western Australia_Private                1
# Tasmania_Private                         7
# Northern Territory_Private               6
# Australian Capital Territory_Private    11
# Australia_Private                        0
# dtype: int64

# %%
# Persist the interpolated/cleaned wide-format vacancies back to CSV
data.to_csv(vac_path, index=False)
